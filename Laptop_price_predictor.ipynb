# %%
# !pip install pandas 
import pandas as pd
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy 
import numpy as np
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0'])
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB',' ')
df['Weight'] = df['Weight'].str.replace('kg',' ')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# ...

# %%
df.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')
df['Price']=df['Price'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int32
# dtypes: float32(1), float64(1), int32(2), object(7)
# memory usage: 96.8+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# ...

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5776\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
sns.barplot(x = df['Company'],y =df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# ...

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x = df['Ram'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = df['Ram'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# ...

# %%
sns.barplot(x = df['TypeName'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = df['Inches'],y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5776\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# ...

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply( lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.tail()
# Out:
#      Company            TypeName  Inches  \
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz    4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
#
# ...

# %%
sns.barplot(x = df['Touchscreen'] , y=df['Price'])
plt.show()

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df['IPS'] = df['ScreenResolution'].apply( lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x = df['IPS'] , y=df['Price'])
plt.show()

# %%
dff = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['x_res'] = dff[0]
df['y_res'] = dff[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df['x_res'] = df['x_res'].astype('int')
df['y_res'] = df['y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int32
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(1), int32(4), int64(2), object(7)
# ...

# %%
df_new = df.select_dtypes(include='number')
df_new.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252207
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['x_res']**2) + (df['y_res']**2))**0.5)/df['Inches']

# %%
df_new = df.select_dtypes(include='number')
df_new.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252207
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df['ScreenResolution'].info
# Out:
# <bound method Series.info of 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object>

# %%
df['Full HD'] = df['ScreenResolution'].apply( lambda x:1 if 'Full HD' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# ...

# %%
df['Full HD'].value_counts()
# Out:
# Full HD
# 1    843
# 0    460
# Name: count, dtype: int64

# %%
sns.barplot(x =df['Full HD'],y=df['Price'])
plt.show()

# %%
df_new = df.select_dtypes(include='number')
df_new.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252207
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Full HD        0.198612
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches','x_res','y_res','ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi  Full HD
# 0  226.983005        0
# 1  127.677940        0
# ...

# %%
df['Cpu_Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi  Full HD       Cpu_Name
# ...

# %%
def proc(t):
    if t=='Intel Core i3' or t=='Intel Core i5' or t=='Intel Core i7':
        return t
    else:
        if t.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu_Name'].apply(proc)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi  Full HD       Cpu_Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts()
# Out:
# Cpu brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.plot()
# Out:
# []

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#           ppi  Full HD       Cpu_Name      Cpu brand
# ...

# %%
df.drop(columns=['Cpu','Cpu_Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi  Full HD      Cpu brand
# 0  macOS    1.37   71378            0    1  226.983005        0  Intel Core i5
# 1  macOS    1.34   47895            0    0  127.677940        0  Intel Core i5
# 2  No OS    1.86   30636            0    0  141.211998        1  Intel Core i5
# 3  macOS    1.83  135195            0    1  220.534624        0  Intel Core i7
# 4  macOS    1.37   96095            0    1  226.983005        0  Intel Core i5

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory']=df['Memory'].str.replace('\.0','',regex=True)

df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5776\1741215731.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory']=df['Memory'].str.replace('\.0','',regex=True)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256 SSD                         412
# 1000 HDD                        224
# 500 HDD                         132
# 512 SSD                         118
# 128 SSD +  1000 HDD              94
# 128 SSD                          76
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 38
# 2000 HDD                         16
# 64 Flash Storage                 15
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 256 SSD +  2000 HDD              10
# 1000 Hybrid                       9
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 512 Flash Storage                 2
# 1000 SSD +  1000 HDD              2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# 256 SSD +  256 SSD                2
# ...

# %%
n_df = df['Memory'].str.split('+',n=1,expand=True)

# %%
n_df
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
df["first"]= n_df[0]
df["first"]=df["first"].str.strip()

df["second"]= n_df[1]

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi  Full HD  \
# 0  macOS    1.37   71378            0    1  226.983005        0
# 1  macOS    1.34   47895            0    0  127.677940        0
# 2  No OS    1.86   30636            0    0  141.211998        1
# 3  macOS    1.83  135195            0    1  220.534624        0
# 4  macOS    1.37   96095            0    1  226.983005        0
#
#        Cpu brand              first second
# 0  Intel Core i5            128 SSD   None
# ...

# %%
df['HDD1']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
df['SSD1']=df['first'].apply(lambda x:1 if 'SSD' in x else 0)
df['Hybrid1']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Flash_s1']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi  Full HD  \
# 0  macOS    1.37   71378            0    1  226.983005        0
# 1  macOS    1.34   47895            0    0  127.677940        0
# 2  No OS    1.86   30636            0    0  141.211998        1
# 3  macOS    1.83  135195            0    1  220.534624        0
# 4  macOS    1.37   96095            0    1  226.983005        0
#
#        Cpu brand              first second  HDD1  SSD1  Hybrid1  Flash_s1
# ...

# %%
df['first'] = df['first'].replace(r'\D','',regex=True)
df["second"].fillna("0", inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi  Full HD  \
# 0  macOS    1.37   71378            0    1  226.983005        0
# 1  macOS    1.34   47895            0    0  127.677940        0
# 2  No OS    1.86   30636            0    0  141.211998        1
# 3  macOS    1.83  135195            0    1  220.534624        0
# 4  macOS    1.37   96095            0    1  226.983005        0
#
#        Cpu brand first second  HDD1  SSD1  Hybrid1  Flash_s1
# 0  Intel Core i5   128      0     0     1        0         0
# ...

# %%
df['HDD2']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['SSD2']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
df['Hybrid2']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Flash_s2']=df['second'].apply(lambda x:1 if 'Flash Storage' in x else 0)

# %%
df['second'].value_counts()
# Out:
# second
# 0                1095
#   1000 HDD        185
#   2000 HDD         15
#   256 SSD           3
#   500 HDD           2
#   1000 Hybrid       2
#   512 SSD           1
# Name: count, dtype: int64

# %%
df['second']=df['second'].replace(r'\D','',regex=True)
df['first'] = df['first'].astype('int')
df['second'] = df['second'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Ram          1303 non-null   int32
#  3   Memory       1303 non-null   object
#  4   Gpu          1303 non-null   object
#  5   OpSys        1303 non-null   object
#  6   Weight       1303 non-null   float32
#  7   Price        1303 non-null   int32
#  8   Touchscreen  1303 non-null   int64
#  9   IPS          1303 non-null   int64
#  10  ppi          1303 non-null   float64
#  11  Full HD      1303 non-null   int64
#  12  Cpu brand    1303 non-null   object
#  13  first        1303 non-null   int32
#  14  second       1303 non-null   int32
#  15  HDD1         1303 non-null   int64
#  16  SSD1         1303 non-null   int64
#  17  Hybrid1      1303 non-null   int64
# ...

# %%
df['HDD'] = (df['first']*df['HDD1'] + df['second']*df['HDD2'])
df['SSD'] = (df['first']*df['SSD1'] + df['second']*df['SSD2'])
df['Hybrid'] = (df['first']*df['Hybrid1'] + df['second']*df['Hybrid2'])
df['Flash Storage'] = (df['first']*df['Flash_s1'] + df['second']*df['Flash_s2'])

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS  ...  Hybrid1  Flash_s1 HDD2  SSD2  \
# 0  macOS    1.37   71378            0    1  ...        0         0    0     0
# 1  macOS    1.34   47895            0    0  ...        0         1    0     0
# 2  No OS    1.86   30636            0    0  ...        0         0    0     0
# 3  macOS    1.83  135195            0    1  ...        0         0    0     0
# 4  macOS    1.37   96095            0    1  ...        0         0    0     0
#
# ...

# %%
df.drop(columns=['first','second','HDD1','HDD2','SSD1','SSD2','Hybrid1','Hybrid2','Flash_s1','Flash_s2'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  IPS         ppi  Full HD  \
# 0  macOS    1.37   71378            0    1  226.983005        0
# 1  macOS    1.34   47895            0    0  127.677940        0
# 2  No OS    1.86   30636            0    0  141.211998        1
# 3  macOS    1.83  135195            0    1  220.534624        0
# 4  macOS    1.37   96095            0    1  226.983005        0
#
#        Cpu brand  HDD  SSD  Hybrid  Flash Storage
# 0  Intel Core i5    0  128       0              0
# ...

# %%
dff = df.select_dtypes(include='number')
dff.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252207
# ppi              0.473487
# Full HD          0.198612
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash Storage   -0.040511
# Name: Price, dtype: float64

# %%
df['HDD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HDD'>

# %%
df.drop(columns=['Memory','Flash Storage','Hybrid'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  IPS         ppi  Full HD      Cpu brand  HDD  SSD
# 0   71378            0    1  226.983005        0  Intel Core i5    0  128
# 1   47895            0    0  127.677940        0  Intel Core i5    0    0
# 2   30636            0    0  141.211998        1  Intel Core i5    0  256
# 3  135195            0    1  220.534624        0  Intel Core i7    0  512
# 4   96095            0    1  226.983005        0  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  IPS         ppi  Full HD      Cpu brand  HDD  SSD  \
# 0   71378            0    1  226.983005        0  Intel Core i5    0  128
# 1   47895            0    0  127.677940        0  Intel Core i5    0    0
# 2   30636            0    0  141.211998        1  Intel Core i5    0  256
# 3  135195            0    1  220.534624        0  Intel Core i7    0  512
# 4   96095            0    1  226.983005        0  Intel Core i5    0  256
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df.drop(columns = ['Gpu Brand'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  IPS         ppi  Full HD      Cpu brand  HDD  SSD
# 0   71378            0    1  226.983005        0  Intel Core i5    0  128
# 1   47895            0    0  127.677940        0  Intel Core i5    0    0
# 2   30636            0    0  141.211998        1  Intel Core i5    0  256
# 3  135195            0    1  220.534624        0  Intel Core i7    0  512
# 4   96095            0    1  226.983005        0  Intel Core i5    0  256

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x : x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  IPS         ppi  Full HD      Cpu brand  HDD  SSD  \
# 0   71378            0    1  226.983005        0  Intel Core i5    0  128
# 1   47895            0    0  127.677940        0  Intel Core i5    0    0
# 2   30636            0    0  141.211998        1  Intel Core i5    0  256
# 3  135195            0    1  220.534624        0  Intel Core i7    0  512
# 4   96095            0    1  226.983005        0  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'])
plt.show()

# %%
df.drop(columns = ['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0    1
#
#           ppi  Full HD      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005        0  Intel Core i5    0  128     Intel
# 1  127.677940        0  Intel Core i5    0    0     Intel
# 2  141.211998        1  Intel Core i5    0  256     Intel
# 3  220.534624        0  Intel Core i7    0  512       AMD
# 4  226.983005        0  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def opsys(t):
    if t=='Windows 10' or t=='Windows 7' or t=='Windows 10 S':
        return 'Windows'
    elif t=='macOS' or t=='Mac OS X':
        return 'Mac'
    elif t=='Linux':
        return 'Linux'
    else:
        return 'No OS/Android/Others'

# %%
df['OpSys'] = df['OpSys'].apply(opsys)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                 OpSys  Weight   Price  Touchscreen  \
# 0   Apple  Ultrabook    8                   Mac    1.37   71378            0
# 1   Apple  Ultrabook    8                   Mac    1.34   47895            0
# 2      HP   Notebook    8  No OS/Android/Others    1.86   30636            0
# 3   Apple  Ultrabook   16                   Mac    1.83  135195            0
# 4   Apple  Ultrabook    8                   Mac    1.37   96095            0
#
#    IPS         ppi  Full HD      Cpu brand  HDD  SSD Gpu brand
# 0    1  226.983005        0  Intel Core i5    0  128     Intel
# 1    0  127.677940        0  Intel Core i5    0    0     Intel
# 2    0  141.211998        1  Intel Core i5    0  256     Intel
# 3    1  220.534624        0  Intel Core i7    0  512       AMD
# 4    1  226.983005        0  Intel Core i5    0  256     Intel

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
sns.regplot(x=df['Weight'],y=df['Price'], scatter=False, color='red')

plt.show()

# %%
dff = df.select_dtypes(include='number')
sns.heatmap(dff.corr())
# Out:
# <Axes: >

# %%
dff.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253319
# ppi            0.475368
# Full HD        0.198093
# HDD           -0.096892
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5776\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram                 OpSys  Weight  \
# 0      Apple           Ultrabook    8                   Mac    1.37
# 1      Apple           Ultrabook    8                   Mac    1.34
# 2         HP            Notebook    8  No OS/Android/Others    1.86
# 3      Apple           Ultrabook   16                   Mac    1.83
# 4      Apple           Ultrabook    8                   Mac    1.37
# ...      ...                 ...  ...                   ...     ...
# 1298  Lenovo  2 in 1 Convertible    4               Windows    1.80
# 1299  Lenovo  2 in 1 Convertible   16               Windows    1.30
# 1300  Lenovo            Notebook    2               Windows    1.50
# 1301      HP            Notebook    6               Windows    2.19
# 1302    Asus            Notebook    4               Windows    2.20
#
#       Touchscreen  IPS         ppi  Full HD              Cpu brand   HDD  SSD  \
# ...

# %%
# !pip install --upgrade scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram                 OpSys  Weight  \
# 183   Toshiba            Notebook    8               Windows    2.00
# 1141      MSI              Gaming    8               Windows    2.40
# 1049     Asus             Netbook    4  No OS/Android/Others    1.20
# 1020     Dell  2 in 1 Convertible    4               Windows    2.08
# 878      Dell            Notebook    4               Windows    2.18
# ...       ...                 ...  ...                   ...     ...
# 466      Acer            Notebook    4               Windows    2.20
# 299      Asus           Ultrabook   16               Windows    1.63
# 493      Acer            Notebook    8               Windows    2.20
# 527    Lenovo            Notebook    8  No OS/Android/Others    2.20
# 1193    Apple           Ultrabook    8                   Mac    0.92
#
#       Touchscreen  IPS         ppi  Full HD              Cpu brand   HDD  SSD  \
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor

# %%
pip install --upgrade xgboost
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: xgboost in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (2.0.3)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.head()
# Out:
#   Company   TypeName  Ram                 OpSys  Weight   Price  Touchscreen  \
# 0   Apple  Ultrabook    8                   Mac    1.37   71378            0
# 1   Apple  Ultrabook    8                   Mac    1.34   47895            0
# 2      HP   Notebook    8  No OS/Android/Others    1.86   30636            0
# 3   Apple  Ultrabook   16                   Mac    1.83  135195            0
# 4   Apple  Ultrabook    8                   Mac    1.37   96095            0
#
#    IPS         ppi  Full HD      Cpu brand  HDD  SSD Gpu brand
# 0    1  226.983005        0  Intel Core i5    0  128     Intel
# 1    0  127.677940        0  Intel Core i5    0    0     Intel
# 2    0  141.211998        1  Intel Core i5    0  256     Intel
# 3    1  220.534624        0  Intel Core i7    0  512       AMD
# 4    1  226.983005        0  Intel Core i5    0  256     Intel

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.01,random_state=2)

# %% [markdown]
# ##LinearRegression##

# %%
categorical_columns = ['Company', 'TypeName', 'OpSys', 'Cpu brand', 'Gpu brand']

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = LinearRegression()
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.8310217564032913
# MAE: 0.2368501531692871

# %% [markdown]
# ##Ridge##

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = Ridge(alpha=10)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.8455926860807417
# MAE: 0.22986923138111223

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = Lasso(alpha=.001)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.8409643196449191
# MAE: 0.23374247615620117

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = KNeighborsRegressor(n_neighbors=1)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.9457791715487952
# MAE: 0.1347368266922586

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = DecisionTreeRegressor(max_depth=8)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.9188469614557948
# MAE: 0.15886114404398224

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')
step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)
pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.8438555031380888
# MAE: 0.21657928705669288

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=17)

pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.9038417586086258
# MAE: 0.17224372625355513

# %% [markdown]
# #*GradientBoostingRegressor*#

# %%
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=4000)

pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.9622810938688205
# MAE: 0.1067379540424284

# %% [markdown]
# *xgboost*

# %%
from xgboost import XGBRegressor
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,9,12])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=100,max_depth=5,learning_rate=0.6)

pipe = Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2_score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2_score: 0.9707204518559465
# MAE: 0.09847700754013987

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')

knn = KNeighborsRegressor(n_neighbors=1)
rf = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=17)
gbdt = GradientBoostingRegressor(n_estimators=4000)
xgb =  XGBRegressor(n_estimators=100,max_depth=5,learning_rate=0.6)

step2 = VotingRegressor([('knn',knn),('rf', rf), ('gbdt', gbdt),('xgb',xgb)],weights=[1,1,1,5])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))

#, ('xgb',xgb)
# Out:
# R2 score 0.9666788361894343
# MAE 0.10836801978243724

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor
step1 = ColumnTransformer(transformers=[
    ('one_hot',OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'),categorical_columns)
],remainder='passthrough')

estimators=[
    ('xgb',XGBRegressor(n_estimators=100,max_depth=5,learning_rate=0.6)),
    ('gbdt' , GradientBoostingRegressor(n_estimators=4000)),
    ('knn' ,KNeighborsRegressor(n_neighbors=1)),
    ('rf' , RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=17)),
]


step2 =  StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9518615798266263
# MAE 0.12891181121780373

# %% [markdown]
# ###Exporting:

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train
# Out:
#      Company     TypeName  Ram                 OpSys  Weight  Touchscreen  \
# 707   Lenovo  Workstation   16               Windows    2.18            0
# 235     Dell     Notebook   16                 Linux    2.36            0
# 477   Lenovo     Notebook    8               Windows    1.70            0
# 1102    Acer     Notebook    4  No OS/Android/Others    2.20            0
# 738      MSI       Gaming   16               Windows    1.80            0
# ...      ...          ...  ...                   ...     ...          ...
# 466     Acer     Notebook    4               Windows    2.20            0
# 299     Asus    Ultrabook   16               Windows    1.63            0
# 493     Acer     Notebook    8               Windows    2.20            0
# 527   Lenovo     Notebook    8  No OS/Android/Others    2.20            0
# 1193   Apple    Ultrabook    8                   Mac    0.92            0
#
#       IPS         ppi  Full HD              Cpu brand   HDD  SSD Gpu brand
# ...

# %% [markdown]
# ##
